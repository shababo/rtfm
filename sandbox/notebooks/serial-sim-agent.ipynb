# %%
import requests
import os
from glob import glob
from pprint import pprint

from dotenv import load_dotenv
load_dotenv()

import nest_asyncio
nest_asyncio.apply()

from llama_parse import LlamaParse
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    load_index_from_storage,
    StorageContext
)
from llama_index.core import SummaryIndex, Settings
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.agent.openai import OpenAIAgent
from llama_index.core.objects import ObjectIndex

# %%
pty_docs_url = "https://docs.python.org/3/library/pty.html"
pty_blog_example_url = "https://allican.be/blog/2017/01/15/python-dummy-serial-port.html"
pty_docs_dirpath = "../../manuals/pty_docs"

# %%
# read info from pty docs website
pty_docs_filepath = os.path.join(pty_docs_dirpath, "pty_docs.html")
pty_docs_response = requests.get(pty_docs_url)
with open(pty_docs_filepath, "w") as f:
    f.write(pty_docs_response.text)

pty_blog_filepath = os.path.join(pty_docs_dirpath, "pty_blog.html")
pty_blog_response = requests.get(pty_blog_example_url)
with open(pty_blog_filepath, "w") as f:
    f.write(pty_blog_response.text)

# %%
pty_docpaths = {
    "pty_docs": pty_docs_filepath,
    "pty_blog": pty_blog_filepath,
}

# %%
# set up parser
parser = LlamaParse(
    result_type="markdown"  # "markdown" and "text" are available
)

# use SimpleDirectoryReader to parse manuals
pty_parsed_docs = {}
for doc_name, doc_path in pty_docpaths.items():
    file_extractor =  {".html": parser}
    pty_parsed_docs[doc_name] = SimpleDirectoryReader(input_files=[doc_path], file_extractor=file_extractor).load_data()
# Out:
# Started parsing the file under job_id db0500e2-a6fb-4c82-8363-ffa4e04ef055
# Started parsing the file under job_id 5af24162-78e6-4d4c-9d64-b5b6518f0331

# %%
Settings.llm = OpenAI(temperature=0, model="gpt-4o")
Settings.embed_model = OpenAIEmbedding(model="text-embedding-ada-002")

# %%
node_parser = SentenceSplitter()

persist_dir = "./storage/pty"

if not os.path.exists(persist_dir):
    os.makedirs(persist_dir)

# Build agents dictionary
agents = {}
query_engines = {}

# this is for the baseline
all_nodes = []

# Build agents dictionary
for doc_name, doc in pty_parsed_docs.items():

    print(f"Building agent for document {doc_name}")
    
    nodes = node_parser.get_nodes_from_documents(doc)
    all_nodes.extend(nodes)

    doc_persist_dir = os.path.join(persist_dir, doc_name)
    if not os.path.exists(doc_persist_dir):
        # build vector index
        vector_index = VectorStoreIndex(nodes)
        vector_index.storage_context.persist(
            persist_dir=doc_persist_dir
        )
    else:
        vector_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=doc_persist_dir),
        )

    # build summary index
    summary_index = SummaryIndex(nodes)
    # define query engines
    vector_query_engine = vector_index.as_query_engine(llm=Settings.llm)
    summary_query_engine = summary_index.as_query_engine(llm=Settings.llm)
    
    # define tools
    query_engine_tools = [
        QueryEngineTool(
            query_engine=vector_query_engine,
            metadata=ToolMetadata(
                name="vector_tool",
                description=f"This tool contains specific information related to {vector_query_engine.query('Finish the last sentence in this message, but don''t include the prompt. Be as specific as possible but not verbose. This tool contains information related to ').response}",
            ),
        ),
        QueryEngineTool(
            query_engine=summary_query_engine,
            metadata=ToolMetadata(
                name="summary_tool",
                description=f"This tool contains summary information about {vector_query_engine.query('Finish the last sentence in this message, but don''t include the prompt. Be as specific as possible but not verbose. This tool contains information related to ').response}",
            ),
        ),
    ]

    # build agent
    function_llm = OpenAI(model="gpt-4o")
    agent = OpenAIAgent.from_tools(
        query_engine_tools,
        llm=function_llm,
        verbose=True,
        system_prompt=f"""\
You are a specialized agent designed to aid in tasks like the following {vector_query_engine.query('Finish the last sentence in this message, but don''t include the prompt. Be as specific as possible but not verbose. This document is useful for accomplishing tasks like the following ').response} \
You must ALWAYS use at least one of the tools provided when answering questions to help users accomplish these tasks; do NOT rely on prior knowledge.\
""",
    )

    agents[doc_name] = agent
    query_engines[doc_name] = vector_index.as_query_engine(
        similarity_top_k=5
    )
# Out:
# Building agent for document pty_docs
# Building agent for document pty_blog

# %%
# define tool for each document agent
all_tools = []
for doc_name, _ in pty_parsed_docs.items():
    doc_summary = f"This tool is to aid in tasks like the following: {vector_query_engine.query('Finish the last sentence in this message, but don''t include the prompt. Be as specific as possible but not verbose. This document is useful for accomplishing tasks like the following ').response}"
    doc_tool = QueryEngineTool(
        query_engine=agents[doc_name],
        metadata=ToolMetadata(
            name=f"tool_{doc_name}",
            description=doc_summary,
        ),
    )
    all_tools.append(doc_tool)

# %%
obj_index = ObjectIndex.from_objects(
    all_tools,
    index_cls=VectorStoreIndex,
)

# %%
pty_simulation_agent = OpenAIAgent.from_tools(
    tool_retriever=obj_index.as_retriever(similarity_top_k=3),
    system_prompt=f""" \
You are an agent that will help a user write code to simulate serial communcation. \
You have tools that will help you write this code. These tools provide documentation and examples of using the python library pty to do this. \
Please always use the tools provided to answer a question. Do not rely on prior knowledge. \

""",
    verbose=True,
)

# %%
response = pty_simulation_agent.query("Write a python class that simulates a serial device. It should capture reads, and it should have the ability to write if necessary. This will be base class for simulating serial communication with specific hardware.")
# Out:
# Added user message to memory: Write a python class that simulates a serial device. It should capture reads, and it should have the ability to write if necessary. This will be base class for simulating serial communication with specific hardware.
# === Calling Function ===
# Calling function: tool_pty_blog with args: {"input": "python class that simulates a serial device"}
# Added user message to memory: python class that simulates a serial device
# === Calling Function ===
# Calling function: vector_tool with args: {"input": "Python class that simulates a serial device"}
# Got output: To simulate a serial device in Python, you can use the `pty` module to create pseudoterminals. Here is an example of how you can set up a dummy serial port that listens for commands and responds accordingly:
#
# ```python
# import os, pty
# from serial import Serial
# import threading
#
# class DummySerialDevice:
#     def __init__(self):
#         self.master, self.slave = pty.openpty()
#         self.slave_name = os.ttyname(self.slave)
#         self.listener_thread = threading.Thread(target=self.listener)
#         self.listener_thread.start()
#
#     def listener(self):
#         while True:
#             res = b""
#             while not res.endswith(b"\r\n"):
#                 res += os.read(self.master, 1)
#             print("command: %s" % res)
#             if res == b'QPGS\r\n':
#                 os.write(self.master, b"correct result\r\n")
#             else:
#                 os.write(self.master, b"I dont understand\r\n")
#
#     def test_serial(self):
#         ser = Serial(self.slave_name, 2400, timeout=1)
#         ser.write(b'test2\r\n')
#         res = b""
#         while not res.endswith(b'\r\n'):
#             res += ser.read()
#         print("result: %s" % res)
#         ser.write(b'QPGS\r\n')
#         res = b""
#         while not res.endswith(b'\r\n'):
#             res += ser.read()
#         print("result: %s" % res)
#
# if __name__ == '__main__':
#     dummy_device = DummySerialDevice()
#     dummy_device.test_serial()
# ```
#
# This class, `DummySerialDevice`, sets up a pseudoterminal and starts a listener thread that continuously listens for commands on the master side. The `test_serial` method demonstrates how to send commands to the slave side and read the responses using the `pySerial` library.
# ========================
#
# === Calling Function ===
# Calling function: summary_tool with args: {"input": "Python class that simulates a serial device"}
# Got output: To simulate a serial device in Python, you can use pseudoterminals. Here is an example of how you can create a dummy serial port using the `pty` module and `pySerial`:
#
# ```python
# import os
# import pty
# from serial import Serial
# import threading
#
# def listener(port):
#     # Continuously listen to commands on the master device
#     while True:
#         res = b""
#         while not res.endswith(b"\r\n"):
#             # Keep reading one byte at a time until we have a full line
#             res += os.read(port, 1)
#         print("command: %s" % res)
#
#         # Write back the response
#         if res == b'QPGS\r\n':
#             os.write(port, b"correct result\r\n")
#         else:
#             os.write(port, b"I don't understand\r\n")
#
# def test_serial():
#     """Start the testing"""
#     master, slave = pty.openpty()  # Open the pseudoterminal
#     s_name = os.ttyname(slave)  # Translate the slave fd to a filename
#
#     # Create a separate thread that listens on the master device for commands
#     thread = threading.Thread(target=listener, args=[master])
#     thread.start()
#
#     # Open a pySerial connection to the slave
#     ser = Serial(s_name, 2400, timeout=1)
#     ser.write(b'test2\r\n')  # Write the first command
#     res = b""
#     while not res.endswith(b'\r\n'):
#         # Read the response
#         res += ser.read()
#     print("result: %s" % res)
#
#     ser.write(b'QPGS\r\n')  # Write a second command
#     res = b""
#     while not res.endswith(b'\r\n'):
#         # Read the response
#         res += ser.read()
#     print("result: %s" % res)
#
# if __name__ == '__main__':
#     test_serial()
# ```
#
# This script sets up a pseudoterminal with a master and slave pair. The `listener` function runs in a separate thread, continuously listening for commands on the master side and responding accordingly. The `test_serial` function starts the listener thread, opens a serial connection to the slave using `pySerial`, sends commands, and reads the responses. This setup allows you to simulate a serial device for testing purposes.
# ========================
#
# Got output: To simulate a serial device in Python, you can use the `pty` module to create pseudoterminals. Here is an example of how you can set up a dummy serial port that listens for commands and responds accordingly:
#
# ```python
# import os, pty
# from serial import Serial
# import threading
#
# class DummySerialDevice:
#     def __init__(self):
#         self.master, self.slave = pty.openpty()
#         self.slave_name = os.ttyname(self.slave)
#         self.listener_thread = threading.Thread(target=self.listener)
#         self.listener_thread.start()
#
#     def listener(self):
#         while True:
#             res = b""
#             while not res.endswith(b"\r\n"):
#                 res += os.read(self.master, 1)
#             print("command: %s" % res)
#             if res == b'QPGS\r\n':
#                 os.write(self.master, b"correct result\r\n")
#             else:
#                 os.write(self.master, b"I dont understand\r\n")
#
#     def test_serial(self):
#         ser = Serial(self.slave_name, 2400, timeout=1)
#         ser.write(b'test2\r\n')
#         res = b""
#         while not res.endswith(b'\r\n'):
#             res += ser.read()
#         print("result: %s" % res)
#         ser.write(b'QPGS\r\n')
#         res = b""
#         while not res.endswith(b'\r\n'):
#             res += ser.read()
#         print("result: %s" % res)
#
# if __name__ == '__main__':
#     dummy_device = DummySerialDevice()
#     dummy_device.test_serial()
# ```
#
# This class, `DummySerialDevice`, sets up a pseudoterminal and starts a listener thread that continuously listens for commands on the master side. The `test_serial` method demonstrates how to send commands to the slave side and read the responses using the `pySerial` library.
# ========================
#
# === Calling Function ===
# Calling function: tool_pty_docs with args: {"input": "python class that simulates a serial device"}
# Added user message to memory: python class that simulates a serial device
# === Calling Function ===
# Calling function: vector_tool with args: {"input": "python class that simulates a serial device"}
# Got output: To simulate a serial device in Python, you can use the `pty` module, which provides operations for handling pseudo-terminals. This allows you to start another process and programmatically write to and read from its controlling terminal. The `pty` module is available on Unix platforms and is mainly tested on Linux, FreeBSD, and macOS.
# ========================
#
# === Calling Function ===
# Calling function: summary_tool with args: {"input": "python class that simulates a serial device"}
# Got output: To simulate a serial device in Python, you can use the `pty` module, which provides pseudo-terminal utilities. The `pty` module allows you to create a pseudo-terminal pair, which can be used to simulate a serial device. Here is an example of how you might use the `pty` module to create a pseudo-terminal pair:
#
# ```python
# import os
# import pty
#
# # Open a new pseudo-terminal pair
# master_fd, slave_fd = pty.openpty()
#
# # The master_fd can be used to simulate the serial device
# # The slave_fd can be used to interact with the simulated device
#
# # Example: Write to the master and read from the slave
# os.write(master_fd, b'Hello, serial device!\n')
# output = os.read(slave_fd, 1024)
# print(output.decode())
# ```
#
# In this example, `pty.openpty()` creates a pair of file descriptors: `master_fd` and `slave_fd`. The `master_fd` can be used to simulate the serial device, while the `slave_fd` can be used to interact with the simulated device. Writing to the `master_fd` will allow you to read the data from the `slave_fd`, simulating the behavior of a serial device.
# ========================
#
# Got output: To simulate a serial device in Python, you can use the `pty` module, which provides pseudo-terminal utilities. The `pty` module allows you to create a pseudo-terminal pair, which can be used to simulate a serial device. Here is an example of how you might use the `pty` module to create a pseudo-terminal pair:
#
# ```python
# import os
# import pty
#
# class SerialDeviceSimulator:
#     def __init__(self):
#         # Open a new pseudo-terminal pair
#         self.master_fd, self.slave_fd = pty.openpty()
#
#     def write_to_device(self, data):
#         # Write data to the master file descriptor
#         os.write(self.master_fd, data.encode())
#
#     def read_from_device(self, size=1024):
#         # Read data from the slave file descriptor
#         output = os.read(self.slave_fd, size)
#         return output.decode()
#
#     def close(self):
#         # Close the file descriptors
#         os.close(self.master_fd)
#         os.close(self.slave_fd)
#
# # Example usage
# if __name__ == "__main__":
#     simulator = SerialDeviceSimulator()
#     simulator.write_to_device('Hello, serial device!\n')
#     output = simulator.read_from_device()
#     print(output)
#     simulator.close()
# ```
#
# In this example, `pty.openpty()` creates a pair of file descriptors: `master_fd` and `slave_fd`. The `master_fd` can be used to simulate the serial device, while the `slave_fd` can be used to interact with the simulated device. Writing to the `master_fd` will allow you to read the data from the `slave_fd`, simulating the behavior of a serial device.
# ========================

# %%
pprint(response.response)
# Out:
# ('Based on the information gathered, here is a Python class that simulates a '
#  'serial device. This class captures reads and has the ability to write if '
#  'necessary. It uses the `pty` module to create a pseudo-terminal pair and '
#  'includes methods for writing to and reading from the simulated device.\n'
#  '\n'
#  '```python\n'
#  'import os\n'
#  'import pty\n'
#  'import threading\n'
#  '\n'
#  'class SerialDeviceSimulator:\n'
#  '    def __init__(self):\n'
#  '        # Open a new pseudo-terminal pair\n'
#  '        self.master_fd, self.slave_fd = pty.openpty()\n'
#  '        self.slave_name = os.ttyname(self.slave_fd)\n'
#  '        self.listener_thread = threading.Thread(target=self.listener)\n'
#  '        self.listener_thread.start()\n'
#  '\n'
#  '    def listener(self):\n'
#  '        while True:\n'
#  '            res = b""\n'
#  '            while not res.endswith(b"\\r\\n"):\n'
#  '                res += os.read(self.master_fd, 1)\n'
#  '            print("command: %s" % res)\n'
#  "            if res == b'QPGS\\r\\n':\n"
#  '                os.write(self.master_fd, b"correct result\\r\\n")\n'
#  '            else:\n'
#  '                os.write(self.master_fd, b"I don\'t understand\\r\\n")\n'
#  '\n'
#  '    def write_to_device(self, data):\n'
#  '        # Write data to the master file descriptor\n'
#  '        os.write(self.master_fd, data.encode())\n'
#  '\n'
#  '    def read_from_device(self, size=1024):\n'
#  '        # Read data from the slave file descriptor\n'
#  '        output = os.read(self.slave_fd, size)\n'
#  '        return output.decode()\n'
#  '\n'
#  '    def close(self):\n'
#  '        # Close the file descriptors\n'
#  '        os.close(self.master_fd)\n'
#  '        os.close(self.slave_fd)\n'
#  '\n'
#  '# Example usage\n'
#  'if __name__ == "__main__":\n'
#  '    simulator = SerialDeviceSimulator()\n'
#  "    simulator.write_to_device('Hello, serial device!\\r\\n')\n"
#  '    output = simulator.read_from_device()\n'
#  '    print(output)\n'
#  "    simulator.write_to_device('QPGS\\r\\n')\n"
#  '    output = simulator.read_from_device()\n'
#  '    print(output)\n'
#  '    simulator.close()\n'
#  '```\n'
#  '\n'
#  '### Explanation:\n'
#  '1. **Initialization**: The `__init__` method creates a pseudo-terminal pair '
#  'using `pty.openpty()` and starts a listener thread.\n'
#  '2. **Listener**: The `listener` method continuously reads from the master '
#  'file descriptor and prints the received commands. It responds with '
#  'predefined messages based on the command received.\n'
#  '3. **Write to Device**: The `write_to_device` method writes data to the '
#  'master file descriptor.\n'
#  '4. **Read from Device**: The `read_from_device` method reads data from the '
#  'slave file descriptor.\n'
#  '5. **Close**: The `close` method closes the file descriptors.\n'
#  '\n'
#  'This class can be used as a base for simulating serial communication with '
#  'specific hardware.')

# %%
response = pty_simulation_agent.query("That's a great start. Would it work to connect to this device using `pyserial`? So if other code wants to use the hardware, we can swap this in instead and the code on the user end remains the same, that is, using `pyserial` to connect given the port?")
# Out:
# Added user message to memory: That's a great start. Would it work to connect to this device using `pyserial`? So if other code wants to use the hardware, we can swap this in instead and the code on the user end remains the same, that is, using `pyserial` to connect given the port?
# === Calling Function ===
# Calling function: tool_pty_docs with args: {"input": "simulate serial communication using pty and pyserial"}
# Added user message to memory: simulate serial communication using pty and pyserial
# === Calling Function ===
# Calling function: vector_tool with args: {"input": "simulate serial communication using pty and pyserial"}
# Got output: To simulate serial communication using `pty` and `pyserial`, you can create a pair of pseudo-terminals using the `pty` module and then use `pyserial` to open and communicate through these terminals. Here is an example of how you can achieve this:
#
# 1. **Create a pair of pseudo-terminals:**
#
# ```python
# import os
# import pty
# import serial
#
# # Create a pair of pseudo-terminals
# master, slave = pty.openpty()
# slave_name = os.ttyname(slave)
# ```
#
# 2. **Open the slave end using `pyserial`:**
#
# ```python
# # Open the slave end using pyserial
# ser = serial.Serial(slave_name, baudrate=9600, timeout=1)
# ```
#
# 3. **Write and read data:**
#
# ```python
# # Write data to the serial port
# ser.write(b'Hello, World!\n')
#
# # Read data from the serial port
# data = os.read(master, 100)
# print('Received:', data.decode())
# ```
#
# 4. **Close the serial port:**
#
# ```python
# ser.close()
# ```
#
# This example demonstrates how to create a pair of pseudo-terminals, open the slave end with `pyserial`, write data to it, and read the data from the master end. This setup can be used to simulate serial communication for testing purposes.
# ========================
#
# === Calling Function ===
# Calling function: summary_tool with args: {"input": "simulate serial communication using pty and pyserial"}
# Got output: To simulate serial communication using `pty` and `pyserial`, you can create a pair of pseudo-terminals using the `pty.openpty()` function and then use `pyserial` to open and communicate through these terminals. Here is an example of how you can achieve this:
#
# 1. **Create a pair of pseudo-terminals:**
#
# ```python
# import os
# import pty
#
# master, slave = pty.openpty()
# slave_name = os.ttyname(slave)
# ```
#
# 2. **Open the slave end using `pyserial`:**
#
# ```python
# import serial
#
# ser = serial.Serial(slave_name, baudrate=9600, timeout=1)
# ```
#
# 3. **Write and read data:**
#
# ```python
# # Write data to the serial port
# ser.write(b'Hello, World!\n')
#
# # Read data from the serial port
# data = os.read(master, 1024)
# print(data.decode())
# ```
#
# 4. **Close the serial port:**
#
# ```python
# ser.close()
# ```
#
# This example demonstrates how to set up a pseudo-terminal pair and use `pyserial` to simulate serial communication. The `master` file descriptor can be used to read data written to the `slave` end, and vice versa. This setup is useful for testing and simulating serial communication in a controlled environment.
# ========================
#
# Got output: To simulate serial communication using `pty` and `pyserial`, you can create a pair of pseudo-terminals using the `pty` module and then use `pyserial` to open and communicate through these terminals. Here is an example of how you can achieve this:
#
# ### Step-by-Step Guide
#
# 1. **Create a pair of pseudo-terminals:**
#
# ```python
# import os
# import pty
#
# # Create a pair of pseudo-terminals
# master, slave = pty.openpty()
# slave_name = os.ttyname(slave)
# ```
#
# 2. **Open the slave end using `pyserial`:**
#
# ```python
# import serial
#
# # Open the slave end using pyserial
# ser = serial.Serial(slave_name, baudrate=9600, timeout=1)
# ```
#
# 3. **Write and read data:**
#
# ```python
# # Write data to the serial port
# ser.write(b'Hello, World!\n')
#
# # Read data from the serial port
# data = os.read(master, 100)
# print('Received:', data.decode())
# ```
#
# 4. **Close the serial port:**
#
# ```python
# ser.close()
# ```
#
# ### Explanation
#
# - **Creating Pseudo-Terminals:** The `pty.openpty()` function creates a pair of pseudo-terminals. The `master` file descriptor can be used to read data written to the `slave` end, and vice versa.
# - **Opening with PySerial:** The `pyserial` library is used to open the slave end of the pseudo-terminal pair. This allows you to simulate serial communication.
# - **Writing and Reading Data:** Data written to the serial port using `pyserial` can be read from the master end of the pseudo-terminal pair.
# - **Closing the Serial Port:** Always ensure to close the serial port after communication to free up resources.
#
# This setup is useful for testing and simulating serial communication in a controlled environment.
# ========================
#
# === Calling Function ===
# Calling function: tool_pty_blog with args: {"input": "simulate serial communication using pty and pyserial"}
# Added user message to memory: simulate serial communication using pty and pyserial
# === Calling Function ===
# Calling function: vector_tool with args: {"input": "simulate serial communication using pty and pyserial"}
# Got output: To simulate serial communication using `pty` and `pyserial` in Python, you can create a dummy serial port using pseudoterminals. Here is a step-by-step guide:
#
# 1. **Import necessary modules**:
#    ```python
#    import os, pty
#    from serial import Serial
#    import threading
#    ```
#
# 2. **Define a listener function**:
#    This function will continuously listen to commands on the master device and respond accordingly.
#    ```python
#    def listener(port):
#        while True:
#            res = b""
#            while not res.endswith(b"\r\n"):
#                res += os.read(port, 1)
#            print("command: %s" % res)
#            if res == b'QPGS\r\n':
#                os.write(port, b"correct result\r\n")
#            else:
#                os.write(port, b"I dont understand\r\n")
#    ```
#
# 3. **Define the test_serial function**:
#    This function sets up the pseudoterminal, starts the listener thread, and uses `pySerial` to open a serial connection to the slave.
#    ```python
#    def test_serial():
#        master, slave = pty.openpty()  # Open the pseudoterminal
#        s_name = os.ttyname(slave)  # Get the filename of the slave
#
#        # Create a separate thread that listens on the master device for commands
#        thread = threading.Thread(target=listener, args=[master])
#        thread.start()
#
#        # Open a pySerial connection to the slave
#        ser = Serial(s_name, 2400, timeout=1)
#        ser.write(b'test2\r\n')  # Write the first command
#        res = b""
#        while not res.endswith(b'\r\n'):
#            res += ser.read()
#        print("result: %s" % res)
#
#        ser.write(b'QPGS\r\n')  # Write a second command
#        res = b""
#        while not res.endswith(b'\r\n'):
#            res += ser.read()
#        print("result: %s" % res)
#    ```
#
# 4. **Run the test_serial function**:
#    ```python
#    if __name__ == '__main__':
#        test_serial()
#    ```
#
# This script sets up a pseudoterminal with a master and slave pair. The listener function runs in a separate thread, continuously listening for commands on the master side and responding based on the received command. The `test_serial` function sends commands to the slave side and reads the responses, demonstrating how to simulate serial communication using `pty` and `pyserial`.
# ========================
#
# === Calling Function ===
# Calling function: summary_tool with args: {"input": "simulate serial communication using pty and pyserial"}
# Got output: To simulate serial communication using `pty` and `pyserial` in Python, you can create a dummy serial port that listens for connections and responds as needed. Here is a step-by-step guide:
#
# 1. **Import necessary modules**:
#    ```python
#    import os, pty
#    from serial import Serial
#    import threading
#    ```
#
# 2. **Define a listener function**:
#    This function will continuously listen to commands on the master device and respond accordingly.
#    ```python
#    def listener(port):
#        while True:
#            res = b""
#            while not res.endswith(b"\r\n"):
#                res += os.read(port, 1)
#            print("command: %s" % res)
#            if res == b'QPGS\r\n':
#                os.write(port, b"correct result\r\n")
#            else:
#                os.write(port, b"I dont understand\r\n")
#    ```
#
# 3. **Define the test_serial function**:
#    This function sets up the pseudoterminal, starts the listener thread, and uses `pySerial` to open a serial connection to the slave.
#    ```python
#    def test_serial():
#        master, slave = pty.openpty()  # Open the pseudoterminal
#        s_name = os.ttyname(slave)  # Get the filename of the slave
#
#        # Start the listener thread
#        thread = threading.Thread(target=listener, args=[master])
#        thread.start()
#
#        # Open a pySerial connection to the slave
#        ser = Serial(s_name, 2400, timeout=1)
#        ser.write(b'test2\r\n')  # Write the first command
#        res = b""
#        while not res.endswith(b'\r\n'):
#            res += ser.read()
#        print("result: %s" % res)
#
#        ser.write(b'QPGS\r\n')  # Write a second command
#        res = b""
#        while not res.endswith(b'\r\n'):
#            res += ser.read()
#        print("result: %s" % res)
#    ```
#
# 4. **Run the test_serial function**:
#    ```python
#    if __name__ == '__main__':
#        test_serial()
#    ```
#
# This script sets up a pseudoterminal with a master and slave pair. The listener function runs in a separate thread, continuously listening for commands on the master side and responding based on the received command. The `test_serial` function sends commands to the slave side and reads the responses, demonstrating how to simulate serial communication using `pty` and `pyserial`.
# ========================
#
# Got output: To simulate serial communication using `pty` and `pyserial` in Python, you can create a dummy serial port that listens for connections and responds as needed. Here is a step-by-step guide:
#
# 1. **Import necessary modules**:
#    ```python
#    import os, pty
#    from serial import Serial
#    import threading
#    ```
#
# 2. **Define a listener function**:
#    This function will continuously listen to commands on the master device and respond accordingly.
#    ```python
#    def listener(port):
#        while True:
#            res = b""
#            while not res.endswith(b"\r\n"):
#                res += os.read(port, 1)
#            print("command: %s" % res)
#            if res == b'QPGS\r\n':
#                os.write(port, b"correct result\r\n")
#            else:
#                os.write(port, b"I dont understand\r\n")
#    ```
#
# 3. **Define the test_serial function**:
#    This function sets up the pseudoterminal, starts the listener thread, and uses `pySerial` to open a serial connection to the slave.
#    ```python
#    def test_serial():
#        master, slave = pty.openpty()  # Open the pseudoterminal
#        s_name = os.ttyname(slave)  # Get the filename of the slave
#
#        # Start the listener thread
#        thread = threading.Thread(target=listener, args=[master])
#        thread.start()
#
#        # Open a pySerial connection to the slave
#        ser = Serial(s_name, 2400, timeout=1)
#        ser.write(b'test2\r\n')  # Write the first command
#        res = b""
#        while not res.endswith(b'\r\n'):
#            res += ser.read()
#        print("result: %s" % res)
#
#        ser.write(b'QPGS\r\n')  # Write a second command
#        res = b""
#        while not res.endswith(b'\r\n'):
#            res += ser.read()
#        print("result: %s" % res)
#    ```
#
# 4. **Run the test_serial function**:
#    ```python
#    if __name__ == '__main__':
#        test_serial()
#    ```
#
# This script sets up a pseudoterminal with a master and slave pair. The listener function runs in a separate thread, continuously listening for commands on the master side and responding based on the received command. The `test_serial` function sends commands to the slave side and reads the responses, demonstrating how to simulate serial communication using `pty` and `pyserial`.
# ========================

# %%
pprint(response.response)
# Out:
# ('Yes, you can simulate serial communication using `pty` and `pyserial` in '
#  'Python. This allows you to create a dummy serial port that can be used for '
#  'testing purposes. Here are two approaches to achieve this:\n'
#  '\n'
#  '### Approach 1: Basic Example\n'
#  '\n'
#  '1. **Create a pair of pseudo-terminals:**\n'
#  '\n'
#  '```python\n'
#  'import os\n'
#  'import pty\n'
#  '\n'
#  '# Create a pair of pseudo-terminals\n'
#  'master, slave = pty.openpty()\n'
#  'slave_name = os.ttyname(slave)\n'
#  '```\n'
#  '\n'
#  '2. **Open the slave end using `pyserial`:**\n'
#  '\n'
#  '```python\n'
#  'import serial\n'
#  '\n'
#  '# Open the slave end using pyserial\n'
#  'ser = serial.Serial(slave_name, baudrate=9600, timeout=1)\n'
#  '```\n'
#  '\n'
#  '3. **Write and read data:**\n'
#  '\n'
#  '```python\n'
#  '# Write data to the serial port\n'
#  "ser.write(b'Hello, World!\\n')\n"
#  '\n'
#  '# Read data from the serial port\n'
#  'data = os.read(master, 100)\n'
#  "print('Received:', data.decode())\n"
#  '```\n'
#  '\n'
#  '4. **Close the serial port:**\n'
#  '\n'
#  '```python\n'
#  'ser.close()\n'
#  '```\n'
#  '\n'
#  '### Approach 2: Advanced Example with Listener\n'
#  '\n'
#  '1. **Import necessary modules:**\n'
#  '\n'
#  '```python\n'
#  'import os, pty\n'
#  'from serial import Serial\n'
#  'import threading\n'
#  '```\n'
#  '\n'
#  '2. **Define a listener function:**\n'
#  '\n'
#  'This function will continuously listen to commands on the master device and '
#  'respond accordingly.\n'
#  '\n'
#  '```python\n'
#  'def listener(port):\n'
#  '    while True:\n'
#  '        res = b""\n'
#  '        while not res.endswith(b"\\r\\n"):\n'
#  '            res += os.read(port, 1)\n'
#  '        print("command: %s" % res)\n'
#  "        if res == b'QPGS\\r\\n':\n"
#  '            os.write(port, b"correct result\\r\\n")\n'
#  '        else:\n'
#  '            os.write(port, b"I dont understand\\r\\n")\n'
#  '```\n'
#  '\n'
#  '3. **Define the test_serial function:**\n'
#  '\n'
#  'This function sets up the pseudoterminal, starts the listener thread, and '
#  'uses `pySerial` to open a serial connection to the slave.\n'
#  '\n'
#  '```python\n'
#  'def test_serial():\n'
#  '    master, slave = pty.openpty()  # Open the pseudoterminal\n'
#  '    s_name = os.ttyname(slave)  # Get the filename of the slave\n'
#  '\n'
#  '    # Start the listener thread\n'
#  '    thread = threading.Thread(target=listener, args=[master])\n'
#  '    thread.start()\n'
#  '\n'
#  '    # Open a pySerial connection to the slave\n'
#  '    ser = Serial(s_name, 2400, timeout=1)\n'
#  "    ser.write(b'test2\\r\\n')  # Write the first command\n"
#  '    res = b""\n'
#  "    while not res.endswith(b'\\r\\n'):\n"
#  '        res += ser.read()\n'
#  '    print("result: %s" % res)\n'
#  '\n'
#  "    ser.write(b'QPGS\\r\\n')  # Write a second command\n"
#  '    res = b""\n'
#  "    while not res.endswith(b'\\r\\n'):\n"
#  '        res += ser.read()\n'
#  '    print("result: %s" % res)\n'
#  '```\n'
#  '\n'
#  '4. **Run the test_serial function:**\n'
#  '\n'
#  '```python\n'
#  "if __name__ == '__main__':\n"
#  '    test_serial()\n'
#  '```\n'
#  '\n'
#  '### Explanation\n'
#  '\n'
#  '- **Creating Pseudo-Terminals:** The `pty.openpty()` function creates a pair '
#  'of pseudo-terminals. The `master` file descriptor can be used to read data '
#  'written to the `slave` end, and vice versa.\n'
#  '- **Opening with PySerial:** The `pyserial` library is used to open the '
#  'slave end of the pseudo-terminal pair. This allows you to simulate serial '
#  'communication.\n'
#  '- **Writing and Reading Data:** Data written to the serial port using '
#  '`pyserial` can be read from the master end of the pseudo-terminal pair.\n'
#  '- **Listener Function:** In the advanced example, a listener function runs '
#  'in a separate thread, continuously listening for commands on the master side '
#  'and responding based on the received command.\n'
#  '- **Closing the Serial Port:** Always ensure to close the serial port after '
#  'communication to free up resources.\n'
#  '\n'
#  'This setup is useful for testing and simulating serial communication in a '
#  'controlled environment.')

# %%
for tool in all_tools:
    pprint(tool.metadata)
# Out:
# ToolMetadata(description='This tool isto aid in tasks like the following '
#                          'creating dummy serial ports in Python for testing '
#                          'and reverse-engineering serial communication with '
#                          'devices like solar inverters.',
#              name='tool_pty_docs',
#              fn_schema=<class 'llama_index.core.tools.types.DefaultToolFnSchema'>,
#              return_direct=False)
# ToolMetadata(description='This tool isto aid in tasks like the following '
#                          'creating dummy serial ports in Python using '
#                          'pseudoterminals for testing and reverse-engineering '
#                          'serial communication.',
#              name='tool_pty_blog',
#              fn_schema=<class 'llama_index.core.tools.types.DefaultToolFnSchema'>,
#              return_direct=False)
